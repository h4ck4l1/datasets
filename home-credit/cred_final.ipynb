# %%
import os,sys,warnings,re,math,gc,time
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["KERAS_BACKEND"] = "tensorflow"
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import polars as pl
import polars.selectors as cs
from glob import glob
from sklearn.metrics import roc_auc_score,auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
import lightgbm as lgb
tf.get_logger().setLevel("ERROR")
# %xmode Minimal
# Out:
# Exception reporting mode: Minimal

# %%
pl.Config.set_fmt_str_lengths(100)
pl.Config.set_thousands_separator(",")
pl.Config.set_float_precision(2)
pl.Config.set_fmt_float("full")
pl.Config.set_tbl_rows(10)
# Out:
# polars.config.Config

# %%
train_base = (
    pl.read_parquet("/home/sohail/Downloads/credit_risk/train/train_base.parquet")
    .select(
        pl.col("case_id").cast(pl.UInt32).alias("case_id_base"),
        cs.contains("date").str.to_date().alias("Date"),
        pl.col("target").cast(pl.UInt8)
    )
    .with_columns(
        pl.col("Date").dt.month().alias("month"),
        pl.col("Date").dt.week().alias("week"),
        pl.col("Date").dt.weekday().alias("weekday"),
        (pl.col("Date").dt.year() - 2019).alias("year")
    )
    .select(~cs.contains("target"),cs.contains("target"))
)
train_base
# Out:
# shape: (1_526_659, 7)
# ┌──────────────┬────────────┬───────┬──────┬─────────┬──────┬────────┐
# │ case_id_base ┆ Date       ┆ month ┆ week ┆ weekday ┆ year ┆ target │
# │ ---          ┆ ---        ┆ ---   ┆ ---  ┆ ---     ┆ ---  ┆ ---    │
# │ u32          ┆ date       ┆ i8    ┆ i8   ┆ i8      ┆ i32  ┆ u8     │
# ╞══════════════╪════════════╪═══════╪══════╪═════════╪══════╪════════╡
# │ 0            ┆ 2019-01-03 ┆ 1     ┆ 1    ┆ 4       ┆ 0    ┆ 0      │
# │ 1            ┆ 2019-01-03 ┆ 1     ┆ 1    ┆ 4       ┆ 0    ┆ 0      │
# │ 2            ┆ 2019-01-04 ┆ 1     ┆ 1    ┆ 5       ┆ 0    ┆ 0      │
# │ 3            ┆ 2019-01-03 ┆ 1     ┆ 1    ┆ 4       ┆ 0    ┆ 0      │
# │ 4            ┆ 2019-01-04 ┆ 1     ┆ 1    ┆ 5       ┆ 0    ┆ 1      │
# │ …            ┆ …          ┆ …     ┆ …    ┆ …       ┆ …    ┆ …      │
# │ 2,703,450    ┆ 2020-10-05 ┆ 10    ┆ 41   ┆ 1       ┆ 1    ┆ 0      │
# │ 2,703,451    ┆ 2020-10-05 ┆ 10    ┆ 41   ┆ 1       ┆ 1    ┆ 0      │
# │ 2,703,452    ┆ 2020-10-05 ┆ 10    ┆ 41   ┆ 1       ┆ 1    ┆ 0      │
# │ 2,703,453    ┆ 2020-10-05 ┆ 10    ┆ 41   ┆ 1       ┆ 1    ┆ 0      │
# │ 2,703,454    ┆ 2020-10-05 ┆ 10    ┆ 41   ┆ 1       ┆ 1    ┆ 0      │
# └──────────────┴────────────┴───────┴──────┴─────────┴──────┴────────┘

# %%
test_base = (
    pl.read_parquet("/home/sohail/Downloads/credit_risk/test/test_base.parquet")
    .select(
        pl.col("case_id").cast(pl.UInt32).alias("case_id_base"),
        cs.contains("date").str.to_date().alias("Date"),
    )
    .with_columns(
        pl.col("Date").dt.month().alias("month"),
        pl.col("Date").dt.week().alias("week"),
        pl.col("Date").dt.weekday().alias("weekday"),
        (pl.col("Date").dt.year() - 2019).alias("year"),
        pl.lit(0).cast(pl.UInt8).alias("target")
    )
)
test_base
# Out:
# shape: (10, 7)
# ┌──────────────┬────────────┬───────┬──────┬─────────┬──────┬────────┐
# │ case_id_base ┆ Date       ┆ month ┆ week ┆ weekday ┆ year ┆ target │
# │ ---          ┆ ---        ┆ ---   ┆ ---  ┆ ---     ┆ ---  ┆ ---    │
# │ u32          ┆ date       ┆ i8    ┆ i8   ┆ i8      ┆ i32  ┆ u8     │
# ╞══════════════╪════════════╪═══════╪══════╪═════════╪══════╪════════╡
# │ 57,543       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,549       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,551       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,552       ┆ 2020-10-07 ┆ 10    ┆ 41   ┆ 3       ┆ 1    ┆ 0      │
# │ 57,569       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,630       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,631       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,632       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,633       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# │ 57,634       ┆ 2020-10-06 ┆ 10    ┆ 41   ┆ 2       ┆ 1    ┆ 0      │
# └──────────────┴────────────┴───────┴──────┴─────────┴──────┴────────┘

# %%
drop_list = [
    "int_shallow_subjectrole_182M",
    "int_shallow_subjectrole_93M",
    "person_depth_empls_employer_name_740M",
    "person_shallow_contaddr_matchlist_1032L",
    "person_shallow_remitter_829L",
    "static_base_applicationcnt_361L",
    "static_base_bankacctype_710L",
    "static_base_commnoinclast6m_3546845L",
    "static_base_deferredmnthsnum_166L",
    "static_base_isdebitcard_729L",
    "static_base_mastercontrelectronic_519L",
    "static_base_mastercontrexist_109L",
    "static_base_paytype1st_925L",
    "static_base_paytype_783L",
    "static_base_typesuite_864L",
    "past_depth_cacccardblochreas_147M",
    "past_depth_cacccardblochreas_147M",
    "int_shallow_financialinstitution_591M",
    "person_depth_empls_economicalst_849M",
    "static_external_assignmentdate_4527235D",
    "int_shallow_purposeofcred_426M",
    "deposit_shallow_num_group1",
    "static_base_cardtype_51L",
    "reg_a_recorddate_4527225D",
    "static_external_responsedate_4527233D",
    "int_shallow_numberofoverdueinstls_834L",
    "int_shallow_numberofoutstandinstls_520L",
    "person_shallow_housetype_905L",
    "person_depth_conts_role_79M",
    "static_base_clientscnt_493L",
    "card_shallow_num_group1",
    "static_external_responsedate_4917613D",
    "static_base_lastrejectcommodtypec_5251769M",
    "static_base_clientscnt_257L"
]

# %% [markdown]
# 1424.28 static_base_clientscnt_1130L
# 1580.23 static_base_clientscnt3m_3712950L
# 1613.62 int_shallow_description_351M
# 1723.46 int_shallow_classificationofcontr_13M
# 2064.03 person_depth_num_group2
# 2150.15 static_base_equalitydataagreement_891L
# 2677.09 static_base_numpmtchanneldd_318L
# 2766.21 static_base_clientscnt_360L
# 2849.83 static_base_applicationscnt_629L
# 2902.95 int_shallow_outstandingamount_354A
# 2908.08 static_base_numinstpaidearly5d_1087L
# 3120.68 past_shallow_actualdpd_943P
# 3232.40 past_shallow_credacc_transactions_402L
# 3279.17 int_shallow_totaloutstanddebtvalue_668A
# 3315.26 past_shallow_cancelreason_3545846M
# 3419.50 static_base_clientscnt_946L
# 3465.42 static_external_responsedate_1012D
# 3488.22 int_shallow_classificationofcontr_400M
# 3562.02 static_base_actualdpdtolerance_344P
# 3571.77 static_base_clientscnt_100L
# 3585.06 static_base_clientscnt_304L
# 3682.52 past_shallow_isbidproduct_390L
# 3720.91 static_external_education_88M
# 3757.75 static_external_pmtcount_693L
# 3840.75 person_shallow_contaddr_smempladdr_334L
# 3952.76 static_base_clientscnt_157L
# 3955.59 int_shallow_contractst_545M
# 3994.07 static_external_pmtcount_4527229L
# 4019.92 static_base_applications30d_658L
# 4183.73 static_base_clientscnt_1022L
# 4365.62 static_base_applicationscnt_464L
# 4915.10 int_shallow_overdueamount_31A

# %%
total_df = (
    pl.read_parquet("/home/sohail/Downloads/total_df.parquet")
    .drop(drop_list)
)
total_df
# Out:
# shape: (1_526_669, 319)
# ┌──────────────┬───────┬──────┬─────────┬───┬───────────────┬──────────────┬──────────────┬────────┐
# │ case_id_base ┆ month ┆ week ┆ weekday ┆ … ┆ reg_c_num_gro ┆ reg_c_pmtamo ┆ reg_c_proces ┆ target │
# │ ---          ┆ ---   ┆ ---  ┆ ---     ┆   ┆ up1           ┆ unt_36A      ┆ singdate_168 ┆ ---    │
# │ u32          ┆ f64   ┆ f64  ┆ f64     ┆   ┆ ---           ┆ ---          ┆ D            ┆ u8     │
# │              ┆       ┆      ┆         ┆   ┆ f64           ┆ f32          ┆ ---          ┆        │
# │              ┆       ┆      ┆         ┆   ┆               ┆              ┆ f64          ┆        │
# ╞══════════════╪═══════╪══════╪═════════╪═══╪═══════════════╪══════════════╪══════════════╪════════╡
# │ 0            ┆ 0.00  ┆ 0.00 ┆ 0.50    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 1            ┆ 0.00  ┆ 0.00 ┆ 0.50    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 2            ┆ 0.00  ┆ 0.00 ┆ 0.67    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 3            ┆ 0.00  ┆ 0.00 ┆ 0.50    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 4            ┆ 0.00  ┆ 0.00 ┆ 0.67    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 1      │
# │ …            ┆ …     ┆ …    ┆ …       ┆ … ┆ …             ┆ …            ┆ …            ┆ …      │
# │ 57,630       ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 57,631       ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 57,632       ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 57,633       ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# │ 57,634       ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.04          ┆ 0.00         ┆ 0.62         ┆ 0      │
# └──────────────┴───────┴──────┴─────────┴───┴───────────────┴──────────────┴──────────────┴────────┘

# %%
train_total = total_df.filter(pl.col("case_id_base").is_in(test_base.select("case_id_base")).not_()).drop("case_id_base")
train_total
# Out:
# shape: (1_526_659, 318)
# ┌───────┬──────┬─────────┬──────┬───┬─────────────────┬─────────────────┬─────────────────┬────────┐
# │ month ┆ week ┆ weekday ┆ year ┆ … ┆ reg_c_num_group ┆ reg_c_pmtamount ┆ reg_c_processin ┆ target │
# │ ---   ┆ ---  ┆ ---     ┆ ---  ┆   ┆ 1               ┆ _36A            ┆ gdate_168D      ┆ ---    │
# │ f64   ┆ f64  ┆ f64     ┆ f64  ┆   ┆ ---             ┆ ---             ┆ ---             ┆ u8     │
# │       ┆      ┆         ┆      ┆   ┆ f64             ┆ f32             ┆ f64             ┆        │
# ╞═══════╪══════╪═════════╪══════╪═══╪═════════════════╪═════════════════╪═════════════════╪════════╡
# │ 0.00  ┆ 0.00 ┆ 0.50    ┆ 0.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.00  ┆ 0.00 ┆ 0.50    ┆ 0.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.00  ┆ 0.00 ┆ 0.67    ┆ 0.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.00  ┆ 0.00 ┆ 0.50    ┆ 0.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.00  ┆ 0.00 ┆ 0.67    ┆ 0.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 1      │
# │ …     ┆ …    ┆ …       ┆ …    ┆ … ┆ …               ┆ …               ┆ …               ┆ …      │
# │ 0.82  ┆ 0.78 ┆ 0.00    ┆ 1.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.82  ┆ 0.78 ┆ 0.00    ┆ 1.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.82  ┆ 0.78 ┆ 0.00    ┆ 1.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.82  ┆ 0.78 ┆ 0.00    ┆ 1.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# │ 0.82  ┆ 0.78 ┆ 0.00    ┆ 1.00 ┆ … ┆ 0.04            ┆ 0.00            ┆ 0.62            ┆ 0      │
# └───────┴──────┴─────────┴──────┴───┴─────────────────┴─────────────────┴─────────────────┴────────┘

# %%
submission_df = total_df.filter(pl.col("case_id_base").is_in(test_base.select("case_id_base"))).drop(["target"])
submission_df
# Out:
# shape: (10, 318)
# ┌─────────────┬───────┬──────┬─────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ case_id_bas ┆ month ┆ week ┆ weekday ┆ … ┆ reg_b_deduc ┆ reg_c_num_g ┆ reg_c_pmtam ┆ reg_c_proce │
# │ e           ┆ ---   ┆ ---  ┆ ---     ┆   ┆ tiondate_49 ┆ roup1       ┆ ount_36A    ┆ ssingdate_1 │
# │ ---         ┆ f64   ┆ f64  ┆ f64     ┆   ┆ 17603D      ┆ ---         ┆ ---         ┆ 68D         │
# │ u32         ┆       ┆      ┆         ┆   ┆ ---         ┆ f64         ┆ f32         ┆ ---         │
# │             ┆       ┆      ┆         ┆   ┆ f64         ┆             ┆             ┆ f64         │
# ╞═════════════╪═══════╪══════╪═════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 57,543      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.84        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,549      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.64        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,551      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,552      ┆ 0.82  ┆ 0.78 ┆ 0.33    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,569      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,630      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,631      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,632      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,633      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# │ 57,634      ┆ 0.82  ┆ 0.78 ┆ 0.17    ┆ … ┆ 0.55        ┆ 0.04        ┆ 0.00        ┆ 0.62        │
# └─────────────┴───────┴──────┴─────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
train_df,valid_df = train_test_split(
    train_total,
    stratify=train_total.select("target"),
    test_size=0.1,
    random_state=420,
    shuffle=True
    )

# %%
print(train_df.shape)
print(valid_df.shape)
# Out:
# (1373993, 318)
# (152666, 318)

# %%
X_train,y_train = train_df.select((~(cs.by_name("target"))).cast(pl.Float32)),train_df.select(pl.col("target").cast(pl.Float32))
X_valid,y_valid = valid_df.select((~(cs.by_name("target"))).cast(pl.Float32)),valid_df.select(pl.col("target").cast(pl.Float32))
del train_df,valid_df

# %%
params = {
    "objective":"binary",
    "boosting_type": "gbdt",
    "metric":"auc",
    "max_depth": 128,
    "learning_rate": 0.005,
    "n_estimators": 20000,
    "colsample_bynode": 0.8,
    "colsample_bytree": 0.8,
    "random_state": 42,
    "reg_alpha": 0.15,
    "reg_lambda": 20,
    "extra_trees": True,
    "num_leaves": 512,
    "device": "gpu",
    "importance_type": "gain",
    "verbose": -1
}

# %%
model = lgb.LGBMClassifier(**params)
model.fit(
    X_train,
    y_train,
    eval_set=[
        (X_valid,y_valid)
        ],
        callbacks=[
            lgb.log_evaluation(100),lgb.early_stopping(2000)
            ]
    )
# Out:
# Training until validation scores don't improve for 2000 rounds
# [100]	valid_0's auc: 0.810998
# [200]	valid_0's auc: 0.818268
# [300]	valid_0's auc: 0.824718
# [400]	valid_0's auc: 0.830101
# [500]	valid_0's auc: 0.834517
# [600]	valid_0's auc: 0.83826
# [700]	valid_0's auc: 0.841174
# [800]	valid_0's auc: 0.843504
# [900]	valid_0's auc: 0.845493
# [1000]	valid_0's auc: 0.847105
# [1100]	valid_0's auc: 0.848473
# [1200]	valid_0's auc: 0.849679
# [1300]	valid_0's auc: 0.850707
# [1400]	valid_0's auc: 0.851662
# [1500]	valid_0's auc: 0.852517
# [1600]	valid_0's auc: 0.853303
# [1700]	valid_0's auc: 0.853966
# [1800]	valid_0's auc: 0.85458
# [1900]	valid_0's auc: 0.855138
# [2000]	valid_0's auc: 0.855628
# [2100]	valid_0's auc: 0.856108
# [2200]	valid_0's auc: 0.85655
# [2300]	valid_0's auc: 0.85698
# [2400]	valid_0's auc: 0.857365
# [2500]	valid_0's auc: 0.857712
# [2600]	valid_0's auc: 0.858049
# [2700]	valid_0's auc: 0.858347
# [2800]	valid_0's auc: 0.858659
# [2900]	valid_0's auc: 0.858901
# [3000]	valid_0's auc: 0.859155
# [3100]	valid_0's auc: 0.859417
# [3200]	valid_0's auc: 0.859633
# [3300]	valid_0's auc: 0.859876

# %% [markdown]
# - 863425 normal
# - 863725 drop gain 256 num leaves
# - 863586 normal
# - 863408 drop split
# - 863139 512 num leaves
# - 863088 512 256
# - 863195 0.8,0.8
# - 86323 0.75, 0.75

# %%
for num,col_name in sorted(zip(model.feature_importances_,X_train.columns)):
    print(f"{num:.2f} {col_name:>10}")
    # print(f'''"{col_name}",''')
# Out:
# 1071.31 static_base_clientscnt_1130L
# 1416.14 person_depth_num_group2
# 1419.94 int_shallow_description_351M
# 1543.99 static_base_clientscnt3m_3712950L
# 1925.95 static_base_numinstpaidearly5d_1087L
# 2341.40 static_base_clientscnt_360L
# 2371.87 past_shallow_credacc_transactions_402L
# 2458.85 int_shallow_classificationofcontr_400M
# 2470.53 static_base_applicationscnt_629L
# 2474.84 static_base_numpmtchanneldd_318L
# 2650.44 int_shallow_totaloutstanddebtvalue_668A
# 2903.52 static_base_applications30d_658L
# 2904.02 past_shallow_actualdpd_943P
# 2933.90 int_shallow_outstandingamount_354A
# 2945.05 static_base_actualdpdtolerance_344P
# 3002.40 int_shallow_classificationofcontr_13M
# 3070.16 static_external_pmtcount_693L
# 3088.79 static_base_clientscnt_946L
# 3102.34 static_base_clientscnt_1022L
# 3111.35 static_base_clientscnt_304L
# 3151.88 static_external_responsedate_1012D
# 3241.94 static_base_clientscnt_100L
# 3334.88 static_base_clientscnt_157L
# 3883.20 static_external_pmtcount_4527229L
# 3938.57 static_external_education_88M
# 4112.08 static_base_applicationscnt_464L
# 4172.76 static_base_numinstpaidearly5dest_4493211L
# 4336.63 int_shallow_overdueamount_31A
# 4704.53 static_base_clientscnt6m_3712949L
# 4763.11 past_shallow_cancelreason_3545846M
# 4854.91 static_base_equalitydataagreement_891L
# 4976.07 static_base_applicationscnt_1086L
# 5213.15 reg_c_num_group1
# 5424.58 past_shallow_credacc_status_367L
# 5577.07 static_base_numinstpaidearlyest_4493214L
# 5694.05 static_base_numcontrs3months_479L
# 5712.02 int_shallow_refreshdate_3813885D
# 5731.11 static_base_numinstpaidearly5dobd_4499205L
# 5999.37 static_base_clientscnt_887L
# 6060.00 int_shallow_purposeofcred_874M
# 6113.77 int_shallow_periodicityofpmts_1102L
# 6364.83 int_shallow_contractst_545M
# 6399.58 person_shallow_contaddr_smempladdr_334L
# 6444.38 past_shallow_isbidproduct_390L
# 6463.69 static_base_numactiverelcontr_750L
# 6530.41 int_shallow_lastupdate_1112D
# 6604.11 static_base_avgdbdtollast24m_4525197P
# 6635.01 static_base_numinstregularpaidest_4493210L
# 6710.65 static_base_lastrejectcommoditycat_161M
# 6827.39 static_base_numinstpaidearly_338L
# 7289.95 int_shallow_totaldebtoverduevalue_718A
# 7355.85 static_base_numinstpaidearly3dest_4493216L
# 7601.45 static_base_numinstpaid_4499208L
# 7602.32 int_shallow_numberofcontrsvalue_258L
# 7643.96 static_base_clientscnt12m_3712952L
# 7871.24 static_base_maxdbddpdtollast6m_4187119P
# 7977.48 static_base_numinstlswithdpd5_4187116L
# 8554.99 reg_b_num_group1
# 8574.84 static_external_maritalst_893M
# 8659.88 past_depth_num_group2
# 8795.02 static_base_numnotactivated_1143L
# 8854.67 int_shallow_contractst_964M
# 9041.41 past_depth_credacc_cards_status_52L
# 9136.74 static_external_secondquarter_766L
# 9168.14 static_base_clientscnt_1071L
# 9480.24 int_shallow_periodicityofpmts_837L
# 9903.57 past_shallow_childnum_21L
# 9953.80 static_base_numinstpaidlastcontr_4325080L
# 10311.29 static_base_numinstregularpaid_973L
# 10512.76 static_base_numinstls_657L
# 10710.06 deposit_shallow_openingdate_313D
# 10913.22 card_shallow_openingdate_857D
# 10962.12 int_shallow_prolongationcount_1120L
# 11262.59 static_base_numactivecreds_622L
# 11291.79 static_base_sellerplacecnt_915L
# 11393.31 person_shallow_personindex_1023L
# 11911.27 static_external_thirdquarter_1082L
# 12028.62 static_base_maxdpdlast3m_392P
# 12694.74 static_base_numinstmatpaidtearly2d_4499204L
# 12736.30 static_external_fourthquarter_440L
# 12828.99 static_base_lastcancelreason_561M
# 13194.12 static_base_maxdpdinstlnum_3546846P
# 13261.23 static_external_firstquarter_103L
# 13337.53 static_base_mindbdtollast24m_4525191P
# 13355.18 static_base_avgdbddpdlast3m_4187120P
# 13375.52 static_base_numinstpaidlate1d_3546852L
# 13579.82 static_base_maxdbddpdlast1m_3658939P
# 13653.82 person_shallow_type_25L
# 14140.65 static_base_validfrom_1069D
# 14421.37 reg_b_deductiondate_4917603D
# 14659.76 past_shallow_credacc_minhisbal_90A
# 15114.52 static_base_numinstpaidearly3d_3546850L
# 15334.31 int_shallow_contractsum_5085717L
# 15506.20 person_shallow_num_group1
# 15630.93 static_base_applicationscnt_867L
# 16335.23 static_base_lastapprcommoditycat_1041M
# 16514.09 static_base_avgdbddpdlast24m_3658932P
# 16867.17 static_external_contractssum_5085716L
# 17461.37 static_base_numinstlallpaidearly3d_817L
# 17492.85 static_base_cntincpaycont9m_3716944L
# 18252.57 person_shallow_empl_industry_691L
# 18391.31 static_base_sellerplacescnt_216L
# 18501.45 past_shallow_credacc_maxhisbal_375A
# 19068.86 static_base_numinsttopaygrest_4493213L
# 19173.92 int_shallow_num_group1
# 19913.74 static_base_numinstunpaidmaxest_4493212L
# 20177.51 static_base_avglnamtstart24m_4525187A
# 21409.79 person_depth_num_group1
# 21627.81 past_depth_conts_type_509L
# 21901.47 static_external_assignmentdate_238D
# 22531.39 int_shallow_numberofoverdueinstls_725L
# 22560.91 past_shallow_revolvingaccount_394A
# 22593.94 int_shallow_numberofinstls_229L
# 23509.26 static_base_homephncnt_628L
# 24244.92 int_shallow_financialinstitution_382M
# 24298.24 static_base_lastst_736L
# 25067.03 static_base_mindbddpdlast24m_3658935P
# 25382.10 static_base_numinstunpaidmax_3546851L
# 25403.91 static_base_clientscnt_533L
# 25428.77 static_base_numinstlswithoutdpd_562L
# 25471.63 static_base_numincomingpmts_3546848L
# 26591.09 static_base_monthsannuity_845L
# 26907.83 static_external_pmtscount_423L
# 27517.20 static_base_numinstlsallpaid_934L
# 27831.78 static_base_maxdpdlast6m_474P
# 28595.26 static_base_numrejects9m_859L
# 29182.30 int_shallow_numberofoutstandinstls_59L
# 29579.43 static_external_pmtaverage_4527227A
# 31760.66 static_base_maxlnamtstart6m_4525199A
# 32105.61 static_base_numactivecredschannel_414L
# 32167.05 deposit_shallow_amount_416A
# 32776.21 past_shallow_isdebitcard_527L
# 33081.72 static_base_maxpmtlast3m_4525190A
# 33239.67 static_base_totinstallast1m_4525188A
# 33247.06 reg_b_amount_4917619A
# 34005.31 static_base_avgpmtlast12m_4525200A
# 34046.36 static_base_numinsttopaygr_769L
# 34910.37 past_shallow_credacc_actualbalance_314A
# 35292.64 person_shallow_education_927M
# 35410.44 past_shallow_rejectreason_755M
# 35716.54 static_external_pmtaverage_3A
# 36798.48 static_base_dtlastpmtallstes_4499206D
# 38674.57 static_base_opencred_647L
# 38845.48 past_shallow_postype_4733339M
# 39640.87 person_shallow_safeguarantyflag_411L
# 39678.07 static_base_avgmaxdpdlast9m_3716943P
# 39895.61 static_base_maxdbddpdtollast12m_3658940P
# 40046.81 static_external_days360_512L
# 41071.31 static_base_lastrejectreasonclient_4145040M
# 41615.33 static_base_posfpd10lastmonth_333P
# 41729.58 int_shallow_numberofinstls_320L
# 43180.47 static_external_numberofqueries_373L
# 43713.35 int_shallow_numberofcontrsvalue_358L
# 43815.08 static_base_maxoutstandbalancel12m_4187113A
# 44237.35 static_base_lastactivateddate_801D
# 44808.02 static_base_lastapprdate_640D
# 44909.19 static_base_twobodfilling_608L
# 45227.84 static_base_datefirstoffer_1144D
# 45288.98 static_base_avgdpdtolclosure24_3658938P
# 45862.92 static_base_maxdpdfrom6mto36m_3546853P
# 45974.36 reg_c_processingdate_168D
# 48738.34 static_base_daysoverduetolerancedd_3976961L
# 48935.13 static_base_annuitynextmonth_57A
# 48998.28 static_base_sumoutstandtotalest_4493215A
# 49502.44 static_base_avginstallast24m_3658937A
# 49568.59 static_base_maininc_215A
# 49823.89 static_base_downpmt_116A
# 50262.50 past_shallow_dateactivated_425D
# 50636.59 past_shallow_approvaldate_319D
# 51248.87 static_base_currdebtcredtyperange_828A
# 51459.90 static_base_maxdpdtolerance_374P
# 51986.11 static_base_posfpd30lastmonth_3976960P
# 52021.83 static_base_avgoutstandbalancel6m_4187114A
# 52358.40 static_base_maxdpdlast9m_1059P
# 53065.71 past_shallow_credamount_590A
# 53324.28 int_shallow_nominalrate_498L
# 54138.62 person_shallow_persontype_792L
# 54630.33 person_shallow_persontype_1072L
# 55141.66 past_depth_num_group1
# 55970.23 reg_a_num_group1
# 56092.51 past_shallow_num_group1
# 56178.00 static_base_maxinstallast24m_3658928A
# 56277.40 past_shallow_dtlastpmt_581D
# 56523.30 int_shallow_overdueamount_659A
# 56638.82 int_shallow_nominalrate_281L
# 57516.24 static_external_birthdate_574D
# 59026.37 int_shallow_totaldebtoverduevalue_178A
# 59667.03 past_shallow_dtlastpmtallstes_3545839D
# 59693.95 int_shallow_dpdmaxdateyear_896T
# 59921.99 static_external_requesttype_4525192L
# 59995.51 int_shallow_dateofcredend_353D
# 60041.59 static_base_posfstqpd30lastmonth_3976962P
# 60548.60 static_base_lastapprcredamount_781A
# 62281.21 static_base_numinstlswithdpd10_728L
# 62287.69 static_base_inittransactionamount_650A
# 62780.66 past_shallow_mainoccupationinc_437A
# 63252.48 past_shallow_currdebt_94A
# 63345.93 static_external_days30_165L
# 64635.16 past_shallow_creationdate_885D
# 65312.38 int_shallow_overdueamountmaxdatemonth_284T
# 65680.82 int_shallow_instlamount_852A
# 66051.63 int_shallow_outstandingamount_362A
# 66459.10 int_shallow_overdueamountmaxdateyear_994T
# 67388.89 static_base_sumoutstandtotal_3546847A
# 68286.29 static_base_inittransactioncode_186L
# 68589.52 person_shallow_language1_981M
# 69267.82 past_shallow_firstnonzeroinstldate_307D
# 69316.81 reg_c_pmtamount_36A
# 69329.17 static_base_lastrejectcredamount_222A
# 70331.40 person_shallow_relationshiptoclient_415T
# 70473.15 static_base_lastrejectreason_759M
# 70517.03 int_shallow_lastupdate_388D
# 71716.74 int_shallow_annualeffectiverate_63L
# 72168.41       year
# 72388.32 past_shallow_byoccupationinc_3656910L
# 72400.19 int_shallow_credlmt_230A
# 72787.82 past_shallow_outstandingdebt_522A
# 72789.32 int_shallow_monthlyinstlamount_674A
# 72823.18 person_shallow_mainoccupationinc_384A
# 73535.30 static_base_lastapplicationdate_877D
# 73887.46 person_shallow_role_1084L
# 74695.22 int_shallow_dateofcredstart_181D
# 74935.70 static_base_maxdebt4_972A
# 76784.90 past_shallow_downpmt_134A
# 77233.09 int_shallow_dateofcredend_289D
# 77265.95 past_shallow_credtype_587L
# 77268.52 int_shallow_annualeffectiverate_199L
# 77701.45 int_shallow_dpdmaxdatemonth_442T
# 78079.71 static_base_credtype_322L
# 78461.03 past_shallow_rejectreasonclient_4145042M
# 79333.56 static_base_firstclxcampaign_1125D
# 79779.07 past_shallow_maxdpdtolerance_577P
# 79878.90 static_base_firstdatedue_489D
# 80173.94 static_base_totaldebt_9A
# 80615.37 static_external_maritalst_385M
# 81370.74 int_shallow_dateofrealrepmt_138D
# 82765.64 static_base_currdebt_22A
# 82953.97 static_base_maxdpdlast12m_727P
# 83375.94 static_external_days180_256L
# 83844.28 int_shallow_overdueamountmaxdatemonth_365T
# 84651.31 static_base_datelastinstal40dpd_247D
# 85019.20 past_shallow_pmtnum_8L
# 85679.64 past_shallow_credacc_credlmt_575A
# 85741.44 int_shallow_dpdmaxdatemonth_89T
# 85744.70 static_base_maxannuity_159A
# 86571.85 past_shallow_tenor_203L
# 87515.44 static_external_days90_310L
# 87838.55 int_shallow_totaloutstanddebtvalue_39A
# 88172.07 person_shallow_relationshiptoclient_642T
# 88613.84 past_shallow_annuity_853A
# 88921.18 int_shallow_monthlyinstlamount_332A
# 90641.93 int_shallow_overdueamountmax_35A
# 91618.49 static_external_days120_123L
# 91755.70 int_shallow_overdueamountmax2_398A
# 92166.80 person_shallow_empl_employedtotal_800L
# 94382.42 static_base_maxdpdinstldate_3546855D
# 95568.22 static_base_amtinstpaidbefduel24m_4187115A
# 96272.15 int_shallow_credlmt_935A
# 96791.86 int_shallow_debtoverdue_47A
# 98918.84 static_base_disbursementtype_67L
# 98925.02       week
# 99789.94 int_shallow_instlamount_768A
# 101249.63 int_shallow_debtoutstand_525A
# 102962.83 past_shallow_inittransactioncode_279L
# 107103.54 static_base_maxdpdlast24m_143P
# 111734.26      month
# 112529.96 static_base_totalsettled_863A
# 113398.20 int_shallow_totalamount_996A
# 116225.66 past_shallow_familystate_726L
# 119913.20 int_shallow_overdueamountmax2date_1002D
# 120321.24 past_shallow_education_1138M
# 120504.63 static_base_pctinstlsallpaidearl3d_427L
# 121923.49 person_shallow_familystate_447L
# 123353.10 int_shallow_residualamount_488A
# 123845.35 static_external_education_1103M
# 124593.40 static_base_datelastunpaid_3546854D
# 128776.94 static_base_mobilephncnt_593L
# 134226.66 int_shallow_overdueamountmaxdateyear_2T
# 135508.78    weekday
# 135543.76 static_base_cntpmts24_3658933L
# 135996.31 static_external_description_5085714M
# 136442.09 static_base_eir_270L
# 136788.90 static_base_interestrate_311L
# 136840.82 static_base_lastdelinqdate_224D
# 147045.04 static_base_disbursedcredamount_1113A
# 148286.81 static_external_dateofbirth_337D
# 157735.53 static_base_credamount_770A
# 158725.94 person_shallow_empl_employedfrom_271D
# 161133.69 int_shallow_overdueamountmax2_14A
# 162958.08 int_shallow_dateofcredstart_739D
# 163845.83 static_base_annuity_780A
# 165948.15 person_shallow_incometype_1044T
# 168655.45 int_shallow_totalamount_6A
# 169860.91 int_shallow_numberofoverdueinstlmaxdat_641D
# 169913.68 int_shallow_overdueamountmax2date_1142D
# 170142.38 past_shallow_employedfrom_700D
# 171128.70 static_base_pctinstlsallpaidlat10d_839L
# 181534.22 reg_a_amount_4527230A
# 181849.77 int_shallow_numberofoverdueinstlmaxdat_148D
# 186146.65 int_shallow_residualamount_856A
# 190572.87 static_base_price_1097A
# 194875.89 static_external_pmtssum_45A
# 200812.16 static_base_isbidproduct_1095L
# 208226.97 int_shallow_dpdmaxdateyear_596T
# 211527.05 static_base_pctinstlsallpaidlate6d_3546844L
# 212900.96 static_base_pmtnum_254L
# 217406.91 int_shallow_numberofoverdueinstlmax_1039L
# 218718.09 int_shallow_numberofoverdueinstlmax_1151L
# 228069.60 int_shallow_dpdmax_757P
# 230627.28 static_base_pctinstlsallpaidlate4d_3546849L
# 246385.00 person_shallow_birth_259D
# 246854.70 int_shallow_dpdmax_139P
# 248079.90 static_base_lastrejectdate_50D
# 281518.65 past_shallow_status_219L
# 333190.94 int_shallow_overdueamountmax_155A
# 357873.26 static_base_pctinstlsallpaidlate1d_3546856L
# 359077.76 person_shallow_sex_738L

# %%
sub_df = pd.DataFrame({
    "case_id": submission_df['case_id_base'].to_list(),
    "score": model.predict_proba(submission_df.drop("case_id_base"))[:,1]
}).set_index("case_id")
sub_df.to_csv("./submission.csv")
